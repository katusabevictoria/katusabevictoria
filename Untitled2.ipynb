# %% [markdown]
# <a href="https://colab.research.google.com/github/katusabevictoria/katusabevictoria/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
names_list = ['brownie','cookie','cake', 'cupcake']
names_list
# Out:
# ['brownie', 'cookie', 'cake', 'cupcake']

# %%
prices_list = [2.25,1.25,9.5, 3.5]
prices_list
# Out:
# [2.25, 1.25, 9.5, 3.5]

# %%
quantities_sold_list = [17, 40, 1, 10]
print(quantities_sold_list)
# Out:
# [17, 40, 1, 10]

# %%
prices_list * quantities_sold_list
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-1d763a827c4f> in <cell line: 1>()
# ----> 1 prices_list * quantities_sold_list
#
# TypeError: can't multiply sequence by non-int of type 'list'

# %%
import numpy as np
prices_array =np.array(prices_list)
prices_array
# Out:
# array([2.25, 1.25, 9.5 , 3.5 ])

# %%
quantities_sold_list_array =np.array(quantities_sold_list)
quantities_sold_list_array
# Out:
# array([17, 40,  1, 10])

# %%
new_prices=[]

# %%
new_prices = prices_array * quantities_sold_list_array
print(f'sold items costed: {new_prices}')
# Out:
# sold items costed: [38.25 50.    9.5  35.  ]

# %%
print(new_prices)
# Out:
# [38.25 50.    9.5  35.  ]

# %%
import pandas as pd

# %%
df = pd.DataFrame({'Name':names_list,
                   'Price':prices_list,
                   "Quantity Sold": quantities_sold_list})
print(df)
# Out:
#       Name  Price  Quantity Sold
# 0  brownie   2.25             17
# 1   cookie   1.25             40
# 2     cake   9.50              1
# 3  cupcake   3.50             10

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
print(df.columns)
# Out:
# Index(['Name', 'Price', 'Quantity Sold'], dtype='object')

# %%
df.values
# Out:
# array([['brownie', 2.25, 17],
#        ['cookie', 1.25, 40],
#        ['cake', 9.5, 1],
#        ['cupcake', 3.5, 10]], dtype=object)

# %%
df.set_index("Name")
# Out:
#          Price  Quantity Sold
# Name
# brownie   2.25             17
# cookie    1.25             40
# cake      9.50              1
# cupcake   3.50             10

# %%
df.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
df['Quantity Sold']
# Out:
# 0    17
# 1    40
# 2     1
# 3    10
# Name: Quantity Sold, dtype: int64

# %%
df
# Out:
#       Name  Price  Quantity Sold
# 0  brownie   2.25             17
# 1   cookie   1.25             40
# 2     cake   9.50              1
# 3  cupcake   3.50             10

# %%
import pandas as pd

filename='/content/Sales.csv'

# %%
df = pd.read_csv(filename)

# %%
df.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 0                     17                     19                     25
# 1                     40                     32                     38
# 2                      1                      2                      0
# 3                     10                     14                     12
# 4                      0                     20                     22
#
#    Quantity Sold (Day 4)
# 0                     25
# 1                     38
# 2                      0
# ...

# %%
df.tail()
# Out:
#                     Item  Student                        Packaging  Price  \
# 7                  scone     Jade  Individually Wrapped  (Plastic)   2.00
# 8                 muffin     Anne      Individually Wrapped (Foil)   1.50
# 9   rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# 10             apple pie    Sally                  Box (Cardboard)  10.00
# 11          key lime pie  Martina                  Box (Cardboard)   9.50
#
#     Expense  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 7      1.25                      0                      8
# 8      0.75                      0                      3
# 9      0.25                      0                      0
# 10     4.00                      0                      0
# 11     4.50                      0                      0
#
#     Quantity Sold (Day 3)  Quantity Sold (Day 4)
# 7                      10                     10
# 8                       4                      4
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   12 non-null     object
#  1   Student                12 non-null     object
#  2   Packaging              12 non-null     object
#  3   Price                  12 non-null     float64
#  4   Expense                12 non-null     float64
#  5   Quantity Sold (Day 1)  12 non-null     int64
#  6   Quantity Sold (Day 2)  12 non-null     int64
#  7   Quantity Sold (Day 3)  12 non-null     int64
#  8   Quantity Sold (Day 4)  12 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 992.0+ bytes

# %%
url = "https://docs.google.com/spreadsheets/d/e/2PACX-1vQNX3oBeyee-rQEulninLyZoBUy3JVUy3wsGkPRl-G-mbjh5iItwBfezeGkDHnwtxnLneBX3Ylm1c64/pub?gid=860339357&single=true&output=csv"
# Read in data from url
df_url = pd.read_csv(url)
# Preview the first five rows
df_url.head()
# Out:
#       Item  Student                        Packaging  Price  Expense  \
# 0  brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1   cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2     cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3  cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4    fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 0                     17                     19                     25
# 1                     40                     32                     38
# 2                      1                      2                      0
# 3                     10                     14                     12
# 4                      0                     20                     22
#
#    Quantity Sold (Day 4)
# 0                     25
# 1                     38
# 2                      0
# ...

# %%
df_url.tail()
# Out:
#                     Item  Student                        Packaging  Price  \
# 7                  scone     Jade  Individually Wrapped  (Plastic)   2.00
# 8                 muffin     Anne      Individually Wrapped (Foil)   1.50
# 9   rice krispies treats  Martina  Individually Wrapped  (Plastic)   1.25
# 10             apple pie    Sally                  Box (Cardboard)  10.00
# 11          key lime pie  Martina                  Box (Cardboard)   9.50
#
#     Expense  Quantity Sold (Day 1)  Quantity Sold (Day 2)  \
# 7      1.25                      0                      8
# 8      0.75                      0                      3
# 9      0.25                      0                      0
# 10     4.00                      0                      0
# 11     4.50                      0                      0
#
#     Quantity Sold (Day 3)  Quantity Sold (Day 4)
# 7                      10                     10
# 8                       4                      4
# ...

# %%
df_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   12 non-null     object
#  1   Student                12 non-null     object
#  2   Packaging              12 non-null     object
#  3   Price                  12 non-null     float64
#  4   Expense                12 non-null     float64
#  5   Quantity Sold (Day 1)  12 non-null     int64
#  6   Quantity Sold (Day 2)  12 non-null     int64
#  7   Quantity Sold (Day 3)  12 non-null     int64
#  8   Quantity Sold (Day 4)  12 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 992.0+ bytes

# %%
df_url.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 9 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Item                   12 non-null     object
#  1   Student                12 non-null     object
#  2   Packaging              12 non-null     object
#  3   Price                  12 non-null     float64
#  4   Expense                12 non-null     float64
#  5   Quantity Sold (Day 1)  12 non-null     int64
#  6   Quantity Sold (Day 2)  12 non-null     int64
#  7   Quantity Sold (Day 3)  12 non-null     int64
#  8   Quantity Sold (Day 4)  12 non-null     int64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 992.0+ bytes

# %%
df_url ="https://drive.google.com/file/d/1-7mcBguuzAV7JWVu2XCpgAO-fO6X2cl0/view"
df_url = pd.read_csv(url)
# Preview the first five rows
df_url.head(8)
# Out:
#            Item  Student                        Packaging  Price  Expense  \
# 0       brownie     Hugo  Individually Wrapped  (Plastic)   2.25     0.25
# 1        cookie    Sally  Individually Wrapped  (Plastic)   1.25     0.50
# 2          cake  Martina            Boxed (Clear Plastic)   9.50     5.00
# 3       cupcake      Joe                Boxed (Cardboard)   3.50     0.75
# 4         fudge     Hugo      Individually Wrapped (Foil)   3.00     1.00
# 5  banana bread     Mark      Individually Wrapped (Foil)   2.75     0.50
# 6         torte     Jade            Boxed (Clear Plastic)  10.50     5.50
# 7         scone     Jade  Individually Wrapped  (Plastic)   2.00     1.25
#
#    Quantity Sold (Day 1)  Quantity Sold (Day 2)  Quantity Sold (Day 3)  \
# 0                     17                     19                     25
# 1                     40                     32                     38
# 2                      1                      2                      0
# ...
