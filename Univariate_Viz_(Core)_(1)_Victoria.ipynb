# %% [markdown]
# <a href="https://colab.research.google.com/github/katusabevictoria/katusabevictoria/blob/main/Univariate_Viz_(Core)_(1)_Victoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
fpath="/content/drive/MyDrive/Colab data uploads/data-cleaning-core.csv"
df = pd.read_csv(fpath)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   PassengerId          891 non-null    int64
#  1   Survived             891 non-null    int64
#  2   Pclass               891 non-null    int64
#  3   Sex                  891 non-null    object
#  4   Age                  891 non-null    float64
#  5   Siblings or Spouses  891 non-null    int64
#  6   Parents or Children  891 non-null    int64
#  7   Fare                 891 non-null    float64
#  8   Embarked             891 non-null    object
# dtypes: float64(2), int64(5), object(2)
# memory usage: 62.8+ KB

# %%
No_of_survived = df['Survived'].sum()
No_of_survived
# Out:
# 342

# %%
Total_Number = df['PassengerId'].sum()
Total_Number
# Out:
# 397386

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
pd.set_option('display.max_columns',100)

# %%
Total_died = (Total_Number - No_of_survived)
Total_died
# Out:
# 397044

# %%
# Plot the counts for Survived vs. Died
plt.figure(figsize=(8, 6))
sns.countplot(data=df, x='Survived', palette='pastel')
plt.title('Counts of Survived vs. Died')
plt.xlabel('Survived')
plt.ylabel('Count')
plt.xticks(ticks=[0, 1], labels=['Died', 'Survived'])
plt.show()
# Out:
# <ipython-input-11-ca52b3ac5fd0>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=df, x='Survived', palette='pastel')

# %% [markdown]
# 2) Plot a histogram of the distribution of Age

# %%
df['Age'].hist()
plt.xlabel('Age')
plt.ylabel('passengers')
plt.title('Distribution of Age')
# Out:
# Text(0.5, 1.0, 'Distribution of Age')

# %% [markdown]
# Plot a boxplot for the Fare column

# %%
df.plot(x='Fare', kind='box')
plt.ylabel('passengers')
plt.title('Passenger Fare')
# Out:
# Text(0.5, 1.0, 'Passenger Fare')
